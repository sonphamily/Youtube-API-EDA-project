# %% [markdown]
# # Data Collection

# %% [markdown]
# Get API access permission from Google Cloud Platform to implement Youtube Data API V3

# %%
# Import important libraries
import isodate
import pandas as pd
from dateutil import parser

# Google API
from googleapiclient.discovery import build

# JSON data format
from IPython.display import JSON

# Data Visualization Packages
import seaborn as sb
import matplotlib.pyplot as plt

# %%
# Copy API Key address from Google Clould Credentials
API_key = 'AIzaSyDLhbR6gSL8Lsd1C1K7u7se5Vmdh3Dp_fs'

# %%
# Get channel ID from Phê Phim channel
# Note: Phê Phim is a top trending Vietnamese Youtube Channel making TVshows, Movies, and TV series reactions with over 1 millions Subscribes
Channel_id = ['UCAJ9i1NhhlnosAGu7QcBEtw'] # this list can contain more than one channel id if want to explore more other youtube channels

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=API_key)

# %%
# create a function to get channel's statistics
def get_channel_stats(youtube, channel_ids):
    
    intergrate_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id = ','.join(Channel_id) # joint all channel ids listed in Channel_id seperate by commas
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideo': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        intergrate_data.append(data)
        
    return(pd.DataFrame(intergrate_data))

# %%
channel_stats = get_channel_stats(youtube, Channel_id)
print(channel_stats)
# Out:
#   channelName subscribers      views totalVideo                playlistId
# 0    Phê Phim     1680000  749918420       2317  UUAJ9i1NhhlnosAGu7QcBEtw

# %%
# create playlistID token
playlistID = "UUAJ9i1NhhlnosAGu7QcBEtw"

# create a function to get videos' ids
def get_vid_id(youtube, playlistid):
    
    vid_ids = []
    request = youtube.playlistItems().list(
            part="snippet, contentDetails",
            playlistId = playlistID,
            maxResults = 50
        )
    response = request.execute()
    
    for item in response['items']:
        vid_ids.append(item['contentDetails']['videoId'])
    
            
    nextPageToken = response.get('nextPageToken')
    while nextPageToken is not None:
        request = youtube.playlistItems().list(
            part = 'contentDetails',
            playlistId = playlistID,
            maxResults = 50,
            pageToken = nextPageToken)
        response = request.execute()
        
       
        for item in response['items']:
            vid_ids.append(item['contentDetails']['videoId'])
            
        nextPageToken = response.get('nextPageToken')
    
    
    return vid_ids

# %%
video_ids = get_vid_id(youtube, playlistID)

# %%
print(video_ids)
# Out:
# ['DEA1beSDTo4', '0xD1qv3xMbw', 'mlV8xrTEcoU', 'HtHn34Ky9lY', 'nGQt_gheVTE', '6kWaicuw-yE', 'QwUbAsQWK8s', 'aPc3zWhh7oo', 'hNgH7iPuTzo', 'rQiNQ2IG8oY', 'HSBfyt4UpBc', 'M-SRlZgCH6Y', 'PxPoAv8ZFpk', 'mQKbUl32sdU', 'IkIr_QD_Klg', 'J8FO0jbNJS4', 'smYkGE9erT8', 'FJGA6w4EQNQ', 'tzblb64AaLc', 'lcOOM3owDaA', '1ep6ezbx8NQ', 'DZ0xazNLx30', 'sWSZVszNa9o', 'HsPi0onehTg', '-d62EQO_R8E', 'DJOs9a_PRF0', 'wbiQ1GvZ2P8', '0y4iQschbs0', '4tZ7TixcDnw', 'WP8SsaBngSI', '75aGDOygj3o', 'HTX-Zhf52fc', 'XlFvYVZRc5A', 'Udd5xu47xkM', 'cuJBWFbvsrQ', '_16KvWAZ66Y', 'N1WXEw9qEsc', 'BIs2KTOVV50', 'hMO9ojGcXjM', '4jyn2NQtg3g', 'LorKZO59Iks', '-aaMONCRNbs', 'TEVbXS2Xxuw', 'WrVeMd-ecak', '0xjsJAQ5En8', 'K8J
dbic4QXuM', '8ZuOZx03peo', 'r4uIRv36Fzg', 'XiavFC-OJUQ', 'REcTPaxVMYk', 'MGuo0LADBdY', 'UgCJjZEwmiI', 'DEqtvVw60Jw', 'WXOiqyxLH6A', 'W-P2c4ASmFs', '33kN__MUuqA', 'mSkomuVvBjE', 'ny9Vy7k_6ys', 'MVI5GT0_CeI', '6RxCgC4Scg4', 'PrqLXbxnrq8', 'jy1L8f2EDbI', 'jKFfKTeqfL4', 'iauQFDZhHBc', 'rElHubeinPY', 'smNHzTG7kYo', 'yA3_y6hawXc', 'Cek1JZWDE4M', 'ZzVrDQpqPq4', 'u9ETSuKxTl8', 'WLO4NgFTMUo', '6i7Ye1UD4Lo', 'BdDFijKAW-M', 'Z7jgxkF3U5c', 'XARb0DdqBTQ', 'y5qOuIDFGEg', 'dsAwFEPm2J0', '_pwbMZb1WNA', 'KE7gcgfitKI', 'YDNZeN75co0', 'J_ZYeOfOkos', '62CPPudlZA4', 'zGGZB1ypWTw', 'Y5yzCqYqB68', 'EfvIeWE8f5Y', 'HjoXL20jQmM', 'geuB_9nSgDI', 's-y3414djJM', 'dpn7ekj7YuM', 'tbP2YPh3R-U', '3aXo9DsiKqw', 'RUx2m4wndVw', '4ulQB0RMuqY', 'ZtyBrzWuPFM', 'pb3IoooFCNA', 'T8K_Kl2cNbw', 'PMzdR0gVmmw', 'Kfg1oTqJmdk', 'ZcR4O4s3_Wg', 'cYnpffCIBK4', '6UmRbbevCcY', '67SkHPW9wv8', 'GvN98o3aaZo', 'I8zHPz7Chjc', 'qjzV1t9SG-k', '3HguNb5pI_s', 'fCWrcYUFa9Y', '6K9PtKTfGRM', 'yNGHjWduPK0', 'z1OU5PV2TOw', 'KW0wJDtQnJ8', 'djzL-bV-mjs', '7VPNTC30WIA', 'Ypc4Zslvyfc', 'J3TJxE4yx9o', 'Waa3yw3ez88', '1N9iLmmxYyc', 'zLtdgZk05BY', 'P7Bjkg9P3nE', '2AP3r3Uj9UY', 'qt7oD5Ml8yw', 'avZygZNTvok', 'W5gUnnzE5c8', 'pmDs9FIzUYA', 'ZwWf6Resknc', '8lM4LCk82Go', 'sI864CQQiT0', 'aYGMfWyKWAE', 'K3wD83mPksQ', '1Lw65hwQjq8', 'FwPk19mHWZA', 'TKRLo9etMNc', 'RCxTbDqFhpY', 'VPP9Ae4MZn8', 'ep5ZBUiMMTo', 'tSSsNackLcU', 'YCvJNAu1F-k', 'EQbiW4Od7sY', 'nmfQAK3f_gQ', 'upi464DffDQ', 'pTepdKRa_zE', 'zITTOtAsIA8', 'TQ5FvWSXA00', 'yyrFNpLs ...

# %%
len(video_ids)
# Out:
# 2314

# %%
def get_vid_info(youtube, video_ids):
    
    videos_data = [] # a dictionary for dataframe format
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
    )
        
        response = request.execute()
    
        for vid in response['items']:
            stats_obtain = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            vid_Id = {}
            vid_Id['video_id'] = vid['id']

            for j in stats_obtain.keys():
                for k in stats_obtain[j]:
                    try:
                        vid_Id[k] = vid[j][k]
                    except: 
                        vid_Id[k] = None
            videos_data.append(vid_Id)
                                     
    return pd.DataFrame(videos_data)

# %%
df_vid = get_vid_info(youtube, video_ids)
df_vid
# Out:
#          video_id channelTitle  \
# 0     DEA1beSDTo4     Phê Phim
# 2309     33571       697           None           31   PT3M11S         hd
# 2310     33043       516           None           80  PT12M44S         hd
# 2311     30962       439           None           33   PT6M45S         hd
# 2312     83642      1801           None          114   PT4M24S         hd
# 2313     79686      2248           None          167      PT5M         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 2309   false
# 2310   false
# 2311   false
# 2312   false
# 2313   false
#
# [2314 rows x 13 columns]

# %% [markdown]
# # Data Pre-processing

# %%
# Check if there is any Null values
df_vid.isnull().sum()
# Out:
# video_id             0
# channelTitle         0
# title                0
# description          0
# tags                56
# publishedAt          0
# viewCount            0
# likeCount            0
# favouriteCount    2314
# commentCount         1
# duration             0
# definition           0
# caption              0
# dtype: int64

# %% [markdown]
# 56 null values at tags variable,
# 2314 null values at favouriteCount variable, and
# 1 null value at commentCount variable

# %%
df_vid.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %% [markdown]
# Some data types such as view count, like count, favourite count, ect. should be in numeric type

# %%
# create columns with numeric variables
num_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'] 
df_vid[num_cols] = df_vid[num_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# double check type of 
df_vid.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount         float64
# likeCount         float64
# favouriteCount    float64
# commentCount      float64
# duration           object
# definition         object
# caption            object
# dtype: object

# %% [markdown]
# Type of numeric variables fixed

# %%
# Published date in the week
df_vid['publishedAt'] = df_vid['publishedAt'].apply(lambda x: parser.parse(x))
df_vid['publishedDayName'] = df_vid['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# Convert videos duration to seconds
df_vid['durationSecs'] = df_vid['duration'].apply(lambda x: isodate.parse_duration(x))
df_vid['durationSecs'] = df_vid['durationSecs'].astype('timedelta64[s]')

# %%
# print two column: duration and duration in second
df_vid[['durationSecs', 'duration']]
# Out:
#       durationSecs  duration
# 0            518.0   PT8M38S
# 1            676.0  PT11M16S
# 2            630.0  PT10M30S
# 3            602.0   PT10M2S
# 4            761.0  PT12M41S
# ...            ...       ...
# 2309         191.0   PT3M11S
# 2310         764.0  PT12M44S
# 2311         405.0   PT6M45S
# 2312         264.0   PT4M24S
# 2313         300.0      PT5M
#
# [2314 rows x 2 columns]

# %%
# Add tags count
df_vid['tagsCount'] = df_vid['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
# double check the whole dataset
df_vid
# Out:
#          video_id channelTitle  \
# 0     DEA1beSDTo4     Phê Phim
# 1     0xD1qv3xMbw     Phê Phim
# 2     mlV8xrTEcoU     Phê Phim
# 3     HtHn34Ky9lY     Phê Phim
# 4     nGQt_gheVTE     Phê Phim
# ...           ...          ...
# 2309  4TnBaKhljew     Phê Phim
# 2310  H7iMvjqHkpM     Phê Phim
# 2311  vXKEeLeqkyE     Phê Phim
# 2312  89ZI3HvhR-4     Phê Phim
# 2313  g0E-gvSD_1o     Phê Phim
#
#                                                   title  \
# 0              Review phim LOVE RESET (Yêu lại vợ ngầu)
# 1     CINEMA PARADISO: Kiệt tác điện ảnh VƯỢT THỜI G...
# 2        Review phim NGƯỜI VỢ CUỐI CÙNG (The Last Wife)
# 3     PHÊ PHIM NEWS: MARVEL sẽ xử lý KHỦNG HOẢNG ra ...
# 4     THE SILENCE OF THE LAMBS: Đàn cừu IM LẶNG & Bư...
# ...                                                 ...
# 2309                Cướp biển vùng Caribbean 5 - REVIEW
# 2310       Game of Thrones - PHÂN TÍCH TRAILER SEASON 7
# 2311           Game of Thrones - 5 DỰ ĐOÁN CHO SEASON 7
# 2312  Alien: Covenant - NHỮNG ĐIỀU CẦN BIẾT TRƯỚC KH...
# 2313             Alien: Covenant - NÊN XEM HAY KHÔNG?
#
#                                             description  \
# 0     Liên hệ hợp tác: contact@pheteam.vn\n\n=======...
# 1     Liên hệ hợp tác: contact@pheteam.vn\n\n=======...
# 2     Liên hệ hợp tác: contact@pheteam.vn\n\n=======...
# 3     Liên hệ hợp tác: contact@pheteam.vn\n\n=======...
# 4     Liên hệ hợp tác: contact@pheteam.vn\n\n=======...
# ...                                                 ...
# 2309  Facebook của bọn tớ: https://facebook.com/phep...
# 2310  Facebook của bọn tớ: https://facebook.com/phep...
# 2311  Facebook của bọn tớ: https://facebook.com/phep...
# 2312  Facebook của bọn tớ: https://facebook.com/phep...
# 2313  Facebook của bọn tớ: https://facebook.com/phep...
#
#                                                    tags  \
# 0     [review phim love reset, review phim yêu lại v...
# 1     [review phim cinema paradiso, review phim rạp ...
# 2     [Review phim NGƯỜI VỢ CUỐI CÙNG (The Last Wife...
# 3     [tin tức điện ảnh, tin tức mới nhất, tin tức đ...
# 4     [THE SILENCE OF THE LAMB: Đàn cừu IM LẶNG & Bư...
# ...                                                 ...
# 2309  [caribe, cướp biển, cướp biển vùng caribe 5, p...
# 2310  [tiếng việt, vietsub, trò chơi vương quyền, tó...
# 2311  [game of thrones, phe phim, phe, phim, season ...
# 2312  [alien, covenant, alien covenant, phim, film, ...
# 2313  [alien, covenant, alien covenant, phim, film, ...
#
#                    publishedAt  viewCount  likeCount  favouriteCount  \
# 0    2023-11-12 11:00:22+00:00    18139.0      434.0             NaN
# 1    2023-11-10 11:00:00+00:00    31208.0     1021.0             NaN
# 2    2023-11-09 11:00:48+00:00   122975.0     2958.0             NaN
# 3    2023-11-08 11:00:14+00:00    70053.0     1827.0             NaN
# 4    2023-11-07 11:00:41+00:00    81303.0     2125.0             NaN
# ...                        ...        ...        ...             ...
# 2309 2017-05-31 10:36:57+00:00    33571.0      697.0             NaN
# 2310 2017-05-30 13:04:17+00:00    33043.0      516.0             NaN
# 2311 2017-05-27 05:02:43+00:00    30962.0      439.0             NaN
# 2312 2017-05-14 06:06:05+00:00    83642.0     1801.0             NaN
# 2313 2017-05-14 06:05:53+00:00    79686.0     2248.0             NaN
#
#       commentCount  duration definition caption publishedDayName  \
# 0             38.0   PT8M38S         hd   false           Sunday
# 1             36.0  PT11M16S         hd   false           Friday
# 2            365.0  PT10M30S         hd   false         Thursday
# 3            100.0   PT10M2S         hd   false        Wednesday
# 4             89.0  PT12M41S         hd   false          Tuesday
# ...            ...       ...        ...     ...              ...
# 2309          31.0   PT3M11S         hd   false        Wednesday
# 2310          80.0  PT12M44S         hd   false          Tuesday
# 2311          33.0   PT6M45S         hd   false         Saturday
# 2312         114.0   PT4M24S         hd   false           Sunday
# 2313         167.0      PT5M         hd   false           Sunday
#
#       durationSecs  tagsCount
# 0            518.0         17
# 1            676.0         13
# 2            630.0         16
# 3            602.0         17
# 4            761.0         13
# ...            ...        ...
# 2309         191.0         19
# 2310         764.0         14
# 2311         405.0         49
# 2312         264.0         36
# 2313         300.0         34
#
# [2314 rows x 16 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Best Performing Videos
